# %%
import requests
import pandas as pd

# %%
r = requests.get("https://gamma-api.polymarket.com/events", 
                 params={"limit": 100, "search": "strike"})
data = r.json()
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       1 r = requests.get("https://gamma-api.polymarket.com/events/slug/strike",
#       2                  params={"limit": 100, "search": "strike"})
#       3 data = r.json()
# ----> 4 df = pd.DataFrame(data)
#
# File ~/Documents/school/baysian_statistics/polymarket/venv/lib/python3.12/site-packages/pandas/core/frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     763     mgr = self._init_mgr(
#     764         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     765     )
#     767 elif isinstance(data, dict):
#     768     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770 elif isinstance(data, ma.MaskedArray):
# ...

# %%
df
# Out:
#        id               ticker                 slug                title  \
# 0   10577    iran-nuclear-test    iran-nuclear-test    Iran Nuclear Test
# 1   10206       openai-browser       openai-browser       OpenAI browser
# 2   11039         cop-earnings         cop-earnings         COP Earnings
# 3   10492     greg-goes-all-in     greg-goes-all-in     Greg Goes All In
# 4   10238        fifa-friendly        fifa-friendly        Fifa Friendly
# ..    ...                  ...                  ...                  ...
# 95  10974  us-cyberattack-iran  us-cyberattack-iran  US CyberAttack Iran
# 96  10330        primeira-liga        primeira-liga        Primeira Liga
# 97  10133         fda-approval         fda-approval         FDA Approval
# 98  11057        csco-earnings        csco-earnings        CSCO Earnings
# 99  10861       dji-monthly-ou       dji-monthly-ou      DJI Monthly O/U
#
#    seriesType recurrence                                              image  \
# ...
